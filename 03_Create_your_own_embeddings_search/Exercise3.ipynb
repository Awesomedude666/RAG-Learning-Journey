# %%
# Exercise 3 : using embedding model

docs = [
    "I love machine learning",
    "I enjoy deep learning",
    "Football is a sport"
]

query = "machine learning"

# %%
docs = [
    "A car is parked outside",
    "Football is a sport",
    "Artificial Intelligence is amazing"
]

query = "automobile"

# for this, tf-idf fails while embedding model retrieved correctly.

# %%
from sentence_transformers import SentenceTransformer

# load embedding model
model = SentenceTransformer("all-MiniLM-L6-V2")

# create embeddings
query_embeddings = model.encode([query])
docs_embeddings = model.encode(docs)
# Out:
# C:\Users\uniqu\AppData\Local\Programs\Python\Python311\Lib\site-packages\huggingface_hub\file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarities = cosine_similarity(
    query_embeddings,
    docs_embeddings
)

# %%
score = similarities[0]

for s in score:
    print(s)

best_idx = score.argmax()
print(docs[best_idx])
# Out:
# 0.44539148
# 0.2566682
# 0.2235873
# A car is parked outside
